# %% [markdown]
# # Gradyan İnişi

# %% [markdown]
# Bu egzersizde, tek bir Gradyan İnişi Epoch'unun adımlarını gerçekleştirmek için gerekli fonksiyonları oluşturacaksınız. Daha sonra fonksiyonları birleştirecek ve tüm Gradyan İnişi prosedürü boyunca bir döngü oluşturacaksınız.

# %% [markdown]
# ## 1. Veri Keşfi

# %% [markdown]
# Sizin için mineral içerikleri olan malzemelerin aşağıdaki veri setini içe aktaracağız

# %%
import pandas as pd

data = pd.read_csv("https://d32aokrjazspmn.cloudfront.net/materials/gradient_descent_ingredients_zinc_phosphorous.csv")
data.head()
# Out:
#                                              aliment      zinc  phosphorus
# 0  Durum wheat pre-cooked. whole grain. cooked. u...  0.120907    0.193784
# 1             Asian noodles. plain. cooked. unsalted  0.047859    0.060329
# 2                      Rice. brown. cooked. unsalted  0.156171    0.201097
# 3                             Rice. cooked. unsalted  0.065491    0.045704
# 4                  Rice. parboiled. cooked. unsalted  0.025189    0.045704

# %% [markdown]
# 👇 `Fosfor` ve `Çinko` arasında bir nebze Doğrusal bir ilişkiyi görselleştirebiliriz.
#
# Aralarında en uygun çizgiyi bulmak için Gradyan İnişi kullanalım!

# %%
import seaborn as sns

sns.scatterplot(data=data, x='zinc', y='phosphorus');

# %% [markdown]
# ❓ İki `np.Array` oluşturun
# - çinko için `data_X`
# - fosfor için `data_Y`

# %%
# YOUR CODE HERE
import numpy as np
data_X = np.array(data.zinc)
data_Y = np.array(data.phosphorus)

# %%
assert (data_X.shape == (53,))
assert (data_Y.shape == (53,))

# %% [markdown]
# ## 2. Bir Epoch Kodlama

# %% [markdown]
# Bu egzersizin bu bölümünde, gradyan inişinin bir epoch $\color {red}{(k)}$ sırasında parametreleri güncellemek için kullanılan temel fonksiyonları tanımlayacaksınız. Aşağıdaki formülü hatırlayın
#
# $$
# \beta_0^{\color {red}{(k+1)}} = \beta_0^{\color {red}{(k)}} - \eta \frac{\partial L}{\partial \beta_0}(\beta^{\color{red}{(k)}})
# $$
#
#
# $$
# \beta_1^{\color {red}{(k+1)}} = \beta_1^{\color {red}{(k)}} - \eta \frac{\partial L}{\partial \beta_1}(\beta^{\color {red}{(k)}})
# $$

# %% [markdown]
# ### 2.1 Hipotez Fonksiyonu

# %% [markdown]
# $$
# \hat{y} =  a x + b
# $$
#
# ❓ Doğrusal Regresyon hipotez fonksiyonunu tanımlayın. `a`'nın eğim ve `b`'nin y-kesiti olmasına izin verin.

# %%
def h(X,a,b):
    y_hat = a*X + b
    return y_hat

# %% [markdown]
# ### 2.2 Kayıp Fonksiyonu

# %% [markdown]
# $$
# Kareler\ Toplamı\ Kaybı = \sum_{i=0}^n (y^{(i)} - \hat{y}^{(i)} )^2
# $$
#
# ❓ Yukarıdaki denklemi kullanarak Hipotez Fonksiyonu için SSR Kayıp Fonksiyonunu tanımlayın. Yeni fonksiyonunuzu yazarken yukarıda kodlanan `h` fonksiyonunu yeniden kullanın.

# %%
import numpy as np

def loss(X,Y,a,b):
    y_hat = h(X,a,b)
    loss = np.sum((Y-y_hat) ** 2)
    return loss

# %% [markdown]
# ❓ Eğer aşağıdaki değerler olsaydı tüm malzemeler veri setimizde hesaplanan toplam Kayıp ne olurdu:
# - a = 1
# - b = 1

# %%
# YOUR CODE HERE
# X data_X, y data_Y
total_loss = loss(data_X, data_Y, 1, 1)
print(total_loss)
# Out:
# 63.868506986115456

# %% [markdown]
# ⚠️ 63.86 değerini alıyor olmalısınız. Eğer almıyorsanız, fonksiyonunuzda bir şeyler yanlış. Devam etmeden önce düzeltin!

# %% [markdown]
# ### 2.3 Gradyan

# %% [markdown]
# $$
# \frac{d\ SSR}{d\ eğim}= \sum_{i=0}^n -2  x_i (y^{(i)} - \hat{y}^{(i)} )
# $$
#
# $$
# \frac{d\ SSR}{d\ y-kesiti}= \sum_{i=0}^n -2(y^{(i)} - \hat{y}^{(i)} )
# $$
#
# ❓ Belirli bir noktada `a` ve `b` parametrelerine göre Kayıp Fonksiyonunun kısmi türevlerini hesaplayan bir fonksiyon tanımlayın.

# %% [markdown]
# <details>
# <summary>💡 İpucu</summary>
# Yine, verilen noktalarda tahminleri hesaplamak için yeni fonksiyonunuzda Hipotez Fonksiyonunu yeniden kullanmalısınız.
# </details>

# %%
def gradient(X,Y,a,b):
    pass  # YOUR CODE HERE
    y_hat = h(X, a, b)
    d_a = np.sum(-2*(Y-y_hat)*X)
    d_b = np.sum(-2*(Y-y_hat))
    return d_a, d_b

# %% [markdown]
# ❓ Fonksiyonunuzu kullanarak, eğer aşağıdaki değerler olsaydı her parametrenin kısmi türevleri ne olurdu:
# - a = 1
# - b = 1

# %%
# YOUR CODE HERE
d_a, d_b = gradient(data_X, data_Y, 1, 1)
d_a, d_b
# Out:
# (48.459065809109006, 115.17923733301406)

# %% [markdown]
# ⚠️ 48.45 ve 115.17 değerlerini alıyor olmalısınız. Eğer almıyorsanız, fonksiyonunuzu düzeltin!

# %% [markdown]
# ### 2.4 Adım Boyutları

# %% [markdown]
# $$
# adım\ boyutu = gradyan \cdot öğrenme\ oranı
# $$

# %% [markdown]
# ❓ Her parametre (`a`,`b`) boyunca, türevleri (`d_a`, `d_b`) ve varsayılan olarak `0.01`'e eşit bir `learning_rate`'e göre adım boyutlarını hesaplayan bir fonksiyon tanımlayın

# %%
def steps(d_a,d_b, learning_rate = 0.01):
    step_a = learning_rate*d_a
    step_b = learning_rate*d_b
    return (step_a, step_b)

# %% [markdown]
# ❓ (`a`,`b`) = (1,1) için yukarıda hesaplanan türevler için atılacak adımlar (`step_a`, `step_b`) ne olurdu?

# %%
# YOUR CODE HERE
step_a, step_b = steps(d_a,d_b, learning_rate = 0.01)
step_a, step_b
# Out:
# (0.4845906580910901, 1.1517923733301405)

# %% [markdown]
# ⚠️ Adımlar `a` için 0.48 ve `b` için 1.15 olmalıdır

# %% [markdown]
# ### 2.5 Parametreleri güncellemek (a, b)

# %% [markdown]
# $$
# güncellenmiş\ parametre = eski\ parametre\ değeri - adım\ boyutu
# $$

# %% [markdown]
# ❓ Eski parametre değerlerinden ve adım boyutlarından güncellenmiş parametre değerlerini hesaplayan bir fonksiyon tanımlayın.

# %%
def update_params(a, b, step_a, step_b):
    a_new = a - step_a
    b_new = b - step_b
    return a_new , b_new

# %% [markdown]
# ### 2.6 Tam bir epoch

# %% [markdown]
# ❓ Az önce oluşturduğunuz fonksiyonları kullanarak, aşağıdaki parametrelerle başlamış olsaydınız ilk Epoch'un sonunda güncellenmiş parametreleri hesaplayın:
# - a = 1
# - b = 1

# %%
# YOUR CODE HERE
update_params(1,1, step_a, step_b)
# Out:
# (0.5154093419089099, -0.1517923733301405)

# %% [markdown]
# ⚠️ Aşağıdaki değerleri alıyor olmalısınız:
#    - updated_a = 0.51
#    - updated_b = -0.15

# %% [markdown]
# ## 3. Gradyan İnişi

# %% [markdown]
# ❓ Artık Gradyan İnişi için gerekli fonksiyonlara sahip olduğunuza göre, yakınsama sağlanana kadar epoch'lar boyunca döngü yapın.
#
# - `a = 1` ve `b = 1` parametrelerini başlatın
# - Yakınsamayı **100 epoch** olarak kabul edin
# - Her yeni epoch'u güncellenmiş parametrelerle başlatmayı unutmayın
# - Her epoch'ta `loss`, `a`, ve `b` değerlerini sırasıyla `loss_history`, `a_history` ve `b_history` adlı listelerine ekleyin

# %%
# YOUR CODE HERE
a = 1
b = 1
loss_history = []
a_history = []
b_history = []

for i in range(100):
    a_history.append(a)
    b_history.append(b)
    loss_epoch = loss(data_X,data_Y,a,b)
    loss_history.append(loss_epoch)
    
    d_a, d_b = gradient(data_X,data_Y,a,b)
    step_a, step_b = steps(d_a,d_b, learning_rate = 0.01)
    
    a, b = update_params(a,b, step_a, step_b)

pd.DataFrame({"a_history":a_history,
              "b_history":b_history,
              "loss_history":loss_history}).tail()
# Out:
#     a_history  b_history  loss_history
# 95   0.768603   0.007119      1.082069
# 96   0.768619   0.007112      1.082069
# 97   0.768633   0.007106      1.082069
# 98   0.768647   0.007100      1.082069
# 99   0.768660   0.007094      1.082069

# %% [markdown]
# ❓ 100 epoch'un sonundaki parametre değerleri nelerdir? Onları sırasıyla `a_100` ve `b_100` değişkenlerine kaydedin

# %%
# YOUR CODE HERE
a_100 = a
b_100 = b
a_100, b_100
# Out:
# (0.768671510620374, 0.00708932115622393)

# %%
# 🧪 Test your code
from nbresult import ChallengeResult
result = ChallengeResult('descent',
                         a_100=a_100,
                         b_100=b_100)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/gonul/.pyenv/versions/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/gonul/workintech_project/S16D4-S-gradient-descent/tests
# plugins: anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 2 items
#
# test_descent.py::TestDescent::test_a PASSED                              [ 50%]
# test_descent.py::TestDescent::test_b PASSED                              [100%]
#
# ============================== 2 passed in 0.08s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/descent.pickle
#
# git commit -m 'Completed descent step'
#
# git push origin master

# %% [markdown]
# ## 4. Görsel kontrol

# %% [markdown]
# ❓ Bu yinelemeli yaklaşımı `gradient_descent()` metoduna sarın, bu metod `new_a`, `new_b` ve şu listeleri içeren bir sözlük olan `history`'yi döndürsün:
# - `loss_history`
# - `a_history`
# - `b_history`

# %%
def gradient_descent(X, Y, a_init=1, b_init=1, learning_rate=0.001, n_epochs=100):
    a = a_init
    b = b_init
    epoch = n_epochs
    loss_history = []
    a_history = []
    b_history = []

    for i in range(epoch):
        a_history.append(a)
        b_history.append(b)
        loss_epoch = loss(data_X,data_Y,a,b)
        loss_history.append(loss_epoch)
        print(f"Epoch #{i + 1}, Loss = {loss_epoch}") 
           
        d_a, d_b = gradient(data_X,data_Y,a,b)
        step_a, step_b = steps(d_a,d_b, learning_rate = learning_rate)
        
        a, b = update_params(a,b, step_a, step_b)
        
    history = {'loss': loss_history, 'a': a_history, 'b': b_history}
    return a, b, history

# %% [markdown]
# ❓ Gradyan İniş'inizin parametrelerini kullanarak Çinko ve Fosfor arasında en uygun çizgiyi çizin.

# %%
# YOUR CODE HERE
a_best, b_best, history = gradient_descent(data_X,data_Y, learning_rate=0.001)
# Out:
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 49.22630594850083
# Epoch #3, Loss = 38.0041062761779
# Epoch #4, Loss = 29.40302168743977
# Epoch #5, Loss = 22.810780603736497
# Epoch #6, Loss = 17.758134141228197
# Epoch #7, Loss = 13.885446918588597
# Epoch #8, Loss = 10.917092039868042
# Epoch #9, Loss = 8.641827246697208
# Epoch #10, Loss = 6.897755076668324
# Epoch #11, Loss = 5.560796233170198
# Epoch #12, Loss = 4.535855502798851
# Epoch #13, Loss = 3.750051258334261
# Epoch #14, Loss = 3.147526506803749
# Epoch #15, Loss = 2.6854720437464703
# Epoch #16, Loss = 2.331078573370289
# Epoch #17, Loss = 2.0592007940698394
# Epoch #18, Loss = 1.8505671387201854
# Epoch #19, Loss = 1.6904077082568134
# Epoch #20, Loss = 1.5674027112469073
# Epoch #21, Loss = 1.4728765412884344
# Epoch #22, Loss = 1.4001801128009483
# Epoch #23, Loss = 1.344217479243815
# Epoch #24, Loss = 1.3010830303034528
# Epoch #25, Loss = 1.267783437504973
# Epoch #26, Loss = 1.2420245515547421
# Epoch #27, Loss = 1.2220480791022241
# Epoch #28, Loss = 1.2065064107650831
# Epoch #29, Loss = 1.1943666885248938
# Epoch #30, Loss = 1.184837282362337
# Epoch #31, Loss = 1.1773114414759789
# Epoch #32, Loss = 1.1713241082111139
# Epoch #33, Loss = 1.1665188199733034
# Epoch #34, Loss = 1.1626223426375724
# Epoch #35, Loss = 1.159425229425081
# Epoch #36, Loss = 1.1567669210958016
# Epoch #37, Loss = 1.1545243266347287
# Epoch #38, Loss = 1.1526030714105249
# Epoch #39, Loss = 1.150930789702083
# Epoch #40, Loss = 1.1494519840417303
# Epoch #41, Loss = 1.1481240853767443
# Epoch #42, Loss = 1.1469144335457464
# Epoch #43, Loss = 1.1457979630903399
# Epoch #44, Loss = 1.144755429640244
# Epoch #45, Loss = 1.1437720505974798
# Epoch #46, Loss = 1.1428364633420511
# Epoch #47, Loss = 1.1419399267882082
# Epoch #48, Loss = 1.1410757094462156
# Epoch #49, Loss = 1.1402386204232005
# Epoch #50, Loss = 1.139424649973508
# Epoch #51, Loss = 1.1386306940085564
# Epoch #52, Loss = 1.137854342953872
# Epoch #53, Loss = 1.1370937199222835
# Epoch #54, Loss = 1.1363473566834001
# Epoch #55, Loss = 1.1356140986004901
# Epoch #56, Loss = 1.1348930317682089
# Epoch #57, Loss = 1.1341834271652889
# Epoch #58, Loss = 1.1334846978476607
# Epoch #59, Loss = 1.1327963661359215
# Epoch #60, Loss = 1.1321180384625908
# Epoch #61, Loss = 1.1314493860899588
# Epoch #62, Loss = 1.1307901303272399
# Epoch #63, Loss = 1.1301400311961047
# Epoch #64, Loss = 1.1294988787391294
# Epoch #65, Loss = 1.1288664863538482
# Epoch #66, Loss = 1.1282426856793182
# Epoch #67, Loss = 1.1276273226725924
# Epoch #68, Loss = 1.1270202545972032
# Epoch #69, Loss = 1.1264213477106881
# Epoch #70, Loss = 1.125830475487912
# Epoch #71, Loss = 1.1252475172550955
# Epoch #72, Loss = 1.124672357138661
# Epoch #73, Loss = 1.1241048832554212
# Epoch #74, Loss = 1.123544987087785
# Epoch #75, Loss = 1.1229925630008135
# Epoch #76, Loss = 1.1224475078680591
# Epoch #77, Loss = 1.121909720780814
# Epoch #78, Loss = 1.1213791028213473
# Epoch #79, Loss = 1.120855556885233
# Epoch #80, Loss = 1.1203389875413565
# Epoch #81, Loss = 1.119829300920837
# Epoch #82, Loss = 1.1193264046281843
# Epoch #83, Loss = 1.1188302076695174
# Epoch #84, Loss = 1.1183406203939341
# Epoch #85, Loss = 1.1178575544449914
# Epoch #86, Loss = 1.1173809227199896
# Epoch #87, Loss = 1.1169106393352826
# Epoch #88, Loss = 1.1164466195962506
# Epoch #89, Loss = 1.1159887799708998
# Epoch #90, Loss = 1.1155370380662772
# Epoch #91, Loss = 1.1150913126070925
# Epoch #92, Loss = 1.114651523416076
# Epoch #93, Loss = 1.1142175913957106
# Epoch #94, Loss = 1.1137894385110554
# Epoch #95, Loss = 1.113366987773453
# Epoch #96, Loss = 1.1129501632249539
# Epoch #97, Loss = 1.1125388899233328
# Epoch #98, Loss = 1.1121330939275964
# Epoch #99, Loss = 1.1117327022839085
# Epoch #100, Loss = 1.1113376430118804

# %% [markdown]
# ## 5. İnişinizi görselleştirin

# %% [markdown]
# 🎯 Hedefimiz kayıp fonksiyonumuzu ve gradyan inişi adımlarını matplotlib'in `contourf` kullanarak 2D yüzey üzerinde çizmektir

# %% [markdown]
# ❓ Çizim için ihtiyacımız olan veriyi oluşturarak başlayın
# - `range_a`: `a` için -1 ile 1 arasında eşit aralıklı 100 değerlik bir aralık
# - `range_b`: `b` için -1 ile 1 arasında eşit aralıklı 100 değerlik bir aralık
# - `Z`: her `Z[j,i]` elementinin `a` = `range_a[i]` ve `b` = `range_b[j]` noktasında kayıp fonksiyonunun değerine eşit olduğu 2D-dizi

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt
sns.scatterplot(x=data_X, y=data_Y)
plt.plot(data_X, h(data_X,a_best,b_best))

# %%
# YOUR CODE HERE
range_a = np.linspace(-1,1,100)
range_b = np.linspace(-1,1,100)

Z = np.zeros((len(range_a),len(range_b)))
for (i, a) in enumerate(range_a):
    for (j, b) in enumerate(range_b):
        Z[j,i] = loss(data_X,data_Y,a,b)

# %% [markdown]
# ❓ Şimdi, tek bir subplot'ta şunları çizin:
# - 3 parametre ile matplotlib [contourf](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.contourf.html) kullanarak kayıp fonksiyonunuzu 2D-yüzey olarak
# - gradyan inişinizi görselleştirmek için tüm geçmiş (a,b) noktalarını kırmızı noktalar olarak serpilme grafiği!
#
# Öğrenme oranınızı değiştirin ve grafik üzerindeki etkisini gözlemleyin!

# %%
# YOUR CODE HERE
plt.contourf(range_a, range_b, Z)
plt.xlabel('a')
plt.ylabel('b')
plt.scatter(history['a'], history['b'], c='r', s=1)
plt.colorbar();

# %% [markdown]
# ❓ [isteğe bağlı] Peki ya 3D? Aşağıda aynı veriyi [plot.ly 3D kontur grafiği](https://plotly.com/python/3d-surface-plots/) üzerinde çizmeyi deneyin

# %%
import plotly.graph_objects as go

surface = go.Surface(x=range_a, y=range_b, z=Z)
scatter = go.Scatter3d(x=history['a'], y=history['b'], z=history['loss'], mode='markers')
fig = go.Figure(data=[surface, scatter])

#fig.update_layout(title='Loss Function', autosize=False, width=500, height=500)
fig.show()

# %% [markdown]
# ❓ `kayıp` değerlerinin geçmişini `epoch` sayısının bir fonksiyonu olarak çizin. 0.001'den 0.01'e kadar `learning_rate`'in birden fazla varyasyonuyla deneyin ve farkı anladığınızdan emin olun

# %%
# YOUR CODE HERE
plt.figure(figsize=(15,8))
for l in np.linspace(0.001, 0.01, num=10):
    a_best, b_best, history = gradient_descent(data_X,data_Y, learning_rate=l)
    plt.plot(history['loss'], label=f'{round(l,5)}')
plt.title("Loss History")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
# Out:
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 49.22630594850083
# Epoch #3, Loss = 38.0041062761779
# Epoch #4, Loss = 29.40302168743977
# Epoch #5, Loss = 22.810780603736497
# Epoch #6, Loss = 17.758134141228197
# Epoch #7, Loss = 13.885446918588597
# Epoch #8, Loss = 10.917092039868042
# Epoch #9, Loss = 8.641827246697208
# Epoch #10, Loss = 6.897755076668324
# Epoch #11, Loss = 5.560796233170198
# Epoch #12, Loss = 4.535855502798851
# Epoch #13, Loss = 3.750051258334261
# Epoch #14, Loss = 3.147526506803749
# Epoch #15, Loss = 2.6854720437464703
# Epoch #16, Loss = 2.331078573370289
# Epoch #17, Loss = 2.0592007940698394
# Epoch #18, Loss = 1.8505671387201854
# Epoch #19, Loss = 1.6904077082568134
# Epoch #20, Loss = 1.5674027112469073
# Epoch #21, Loss = 1.4728765412884344
# Epoch #22, Loss = 1.4001801128009483
# Epoch #23, Loss = 1.344217479243815
# Epoch #24, Loss = 1.3010830303034528
# Epoch #25, Loss = 1.267783437504973
# Epoch #26, Loss = 1.2420245515547421
# Epoch #27, Loss = 1.2220480791022241
# Epoch #28, Loss = 1.2065064107650831
# Epoch #29, Loss = 1.1943666885248938
# Epoch #30, Loss = 1.184837282362337
# Epoch #31, Loss = 1.1773114414759789
# Epoch #32, Loss = 1.1713241082111139
# Epoch #33, Loss = 1.1665188199733034
# Epoch #34, Loss = 1.1626223426375724
# Epoch #35, Loss = 1.159425229425081
# Epoch #36, Loss = 1.1567669210958016
# Epoch #37, Loss = 1.1545243266347287
# Epoch #38, Loss = 1.1526030714105249
# Epoch #39, Loss = 1.150930789702083
# Epoch #40, Loss = 1.1494519840417303
# Epoch #41, Loss = 1.1481240853767443
# Epoch #42, Loss = 1.1469144335457464
# Epoch #43, Loss = 1.1457979630903399
# Epoch #44, Loss = 1.144755429640244
# Epoch #45, Loss = 1.1437720505974798
# Epoch #46, Loss = 1.1428364633420511
# Epoch #47, Loss = 1.1419399267882082
# Epoch #48, Loss = 1.1410757094462156
# Epoch #49, Loss = 1.1402386204232005
# Epoch #50, Loss = 1.139424649973508
# Epoch #51, Loss = 1.1386306940085564
# Epoch #52, Loss = 1.137854342953872
# Epoch #53, Loss = 1.1370937199222835
# Epoch #54, Loss = 1.1363473566834001
# Epoch #55, Loss = 1.1356140986004901
# Epoch #56, Loss = 1.1348930317682089
# Epoch #57, Loss = 1.1341834271652889
# Epoch #58, Loss = 1.1334846978476607
# Epoch #59, Loss = 1.1327963661359215
# Epoch #60, Loss = 1.1321180384625908
# Epoch #61, Loss = 1.1314493860899588
# Epoch #62, Loss = 1.1307901303272399
# Epoch #63, Loss = 1.1301400311961047
# Epoch #64, Loss = 1.1294988787391294
# Epoch #65, Loss = 1.1288664863538482
# Epoch #66, Loss = 1.1282426856793182
# Epoch #67, Loss = 1.1276273226725924
# Epoch #68, Loss = 1.1270202545972032
# Epoch #69, Loss = 1.1264213477106881
# Epoch #70, Loss = 1.125830475487912
# Epoch #71, Loss = 1.1252475172550955
# Epoch #72, Loss = 1.124672357138661
# Epoch #73, Loss = 1.1241048832554212
# Epoch #74, Loss = 1.123544987087785
# Epoch #75, Loss = 1.1229925630008135
# Epoch #76, Loss = 1.1224475078680591
# Epoch #77, Loss = 1.121909720780814
# Epoch #78, Loss = 1.1213791028213473
# Epoch #79, Loss = 1.120855556885233
# Epoch #80, Loss = 1.1203389875413565
# Epoch #81, Loss = 1.119829300920837
# Epoch #82, Loss = 1.1193264046281843
# Epoch #83, Loss = 1.1188302076695174
# Epoch #84, Loss = 1.1183406203939341
# Epoch #85, Loss = 1.1178575544449914
# Epoch #86, Loss = 1.1173809227199896
# Epoch #87, Loss = 1.1169106393352826
# Epoch #88, Loss = 1.1164466195962506
# Epoch #89, Loss = 1.1159887799708998
# Epoch #90, Loss = 1.1155370380662772
# Epoch #91, Loss = 1.1150913126070925
# Epoch #92, Loss = 1.114651523416076
# Epoch #93, Loss = 1.1142175913957106
# Epoch #94, Loss = 1.1137894385110554
# Epoch #95, Loss = 1.113366987773453
# Epoch #96, Loss = 1.1129501632249539
# Epoch #97, Loss = 1.1125388899233328
# Epoch #98, Loss = 1.1121330939275964
# Epoch #99, Loss = 1.1117327022839085
# Epoch #100, Loss = 1.1113376430118804
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 36.52877837906954
# Epoch #3, Loss = 21.112347930699748
# Epoch #4, Loss = 12.418780781769845
# Epoch #5, Loss = 7.515863329031883
# Epoch #6, Loss = 4.75029567557211
# Epoch #7, Loss = 3.1898805438932647
# Epoch #8, Loss = 2.3090071185896126
# Epoch #9, Loss = 1.811314281856185
# Epoch #10, Loss = 1.5297010664325101
# Epoch #11, Loss = 1.3699485571909924
# Epoch #12, Loss = 1.278931668307566
# Epoch #13, Loss = 1.2266956738445058
# Epoch #14, Loss = 1.1963502397547658
# Epoch #15, Loss = 1.178371275249201
# Epoch #16, Loss = 1.1673880886786683
# Epoch #17, Loss = 1.16037185731901
# Epoch #18, Loss = 1.1556142138823144
# Epoch #19, Loss = 1.1521513323890162
# Epoch #20, Loss = 1.1494392043739308
# Epoch #21, Loss = 1.1471705462403814
# Epoch #22, Loss = 1.1451715639199236
# Epoch #23, Loss = 1.1433437442791612
# Epoch #24, Loss = 1.141631034414175
# Epoch #25, Loss = 1.1400013356594114
# Epoch #26, Loss = 1.1384360688137132
# Epoch #27, Loss = 1.1369242902502525
# Epoch #28, Loss = 1.1354593740056942
# Epoch #29, Loss = 1.1340371406798686
# Epoch #30, Loss = 1.1326548021137204
# Epoch #31, Loss = 1.1313103660441244
# Epoch #32, Loss = 1.1300023001203239
# Epoch #33, Loss = 1.1287293421668756
# Epoch #34, Loss = 1.1274903929140736
# Epoch #35, Loss = 1.1262844552344815
# Epoch #36, Loss = 1.1251105996089157
# Epoch #37, Loss = 1.1239679443888881
# Epoch #38, Loss = 1.1228556444089455
# Epoch #39, Loss = 1.121772884313882
# Epoch #40, Loss = 1.1207188745510765
# Epoch #41, Loss = 1.1196928488720432
# Epoch #42, Loss = 1.118694062691277
# Epoch #43, Loss = 1.1177217919346456
# Epoch #44, Loss = 1.1167753321698122
# Epoch #45, Loss = 1.1158539979015285
# Epoch #46, Loss = 1.1149571219655765
# Epoch #47, Loss = 1.1140840549838744
# Epoch #48, Loss = 1.1132341648594664
# Epoch #49, Loss = 1.1124068362992425
# Epoch #50, Loss = 1.1116014703574149
# Epoch #51, Loss = 1.1108174839956628
# Epoch #52, Loss = 1.1100543096575282
# Epoch #53, Loss = 1.1093113948555549
# Epoch #54, Loss = 1.1085882017702047
# Epoch #55, Loss = 1.1078842068598824
# Epoch #56, Loss = 1.1071989004815714
# Epoch #57, Loss = 1.1065317865216888
# Epoch #58, Loss = 1.1058823820368182
# Epoch #59, Loss = 1.1052502169040326
# Epoch #60, Loss = 1.1046348334805178
# Epoch #61, Loss = 1.104035786272258
# Epoch #62, Loss = 1.1034526416115102
# Epoch #63, Loss = 1.1028849773428602
# Epoch #64, Loss = 1.1023323825176026
# Epoch #65, Loss = 1.1017944570962463
# Epoch #66, Loss = 1.101270811658908
# Epoch #67, Loss = 1.1007610671234034
# Epoch #68, Loss = 1.1002648544708158
# Epoch #69, Loss = 1.0997818144783522
# Epoch #70, Loss = 1.0993115974592933
# Epoch #71, Loss = 1.098853863009843
# Epoch #72, Loss = 1.0984082797627013
# Epoch #73, Loss = 1.0979745251471773
# Epoch #74, Loss = 1.097552285155671
# Epoch #75, Loss = 1.097141254116355
# Epoch #76, Loss = 1.0967411344718874
# Epoch #77, Loss = 1.0963516365640043
# Epoch #78, Loss = 1.0959724784238247
# Epoch #79, Loss = 1.0956033855677285
# Epoch #80, Loss = 1.0952440907986463
# Epoch #81, Loss = 1.0948943340126294
# Epoch #82, Loss = 1.0945538620105542
# Epoch #83, Loss = 1.0942224283148214
# Epoch #84, Loss = 1.0938997929909258
# Epoch #85, Loss = 1.0935857224737577
# Epoch #86, Loss = 1.0932799893985234
# Epoch #87, Loss = 1.092982372436145
# Epoch #88, Loss = 1.0926926561330341
# Epoch #89, Loss = 1.092410630755121
# Epoch #90, Loss = 1.0921360921360204
# Epoch #91, Loss = 1.09186884152923
# Epoch #92, Loss = 1.0916086854642504
# Epoch #93, Loss = 1.0913554356065298
# Epoch #94, Loss = 1.091108908621119
# Epoch #95, Loss = 1.0908689260399544
# Epoch #96, Loss = 1.0906353141326546
# Epoch #97, Loss = 1.090407903780756
# Epoch #98, Loss = 1.0901865303552811
# Epoch #99, Loss = 1.0899710335975596
# Epoch #100, Loss = 1.0897612575032118
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 25.775924277821687
# Epoch #3, Loss = 10.829689705016193
# Epoch #4, Loss = 4.963882278709413
# Epoch #5, Loss = 2.6604275317592205
# Epoch #6, Loss = 1.7545772648950324
# Epoch #7, Loss = 1.3970956462113224
# Epoch #8, Loss = 1.254823400299816
# Epoch #9, Loss = 1.1970585801153788
# Epoch #10, Loss = 1.172523521042003
# Epoch #11, Loss = 1.1610988864885787
# Epoch #12, Loss = 1.1548888954978147
# Epoch #13, Loss = 1.1507931935792344
# Epoch #14, Loss = 1.1475927878427234
# Epoch #15, Loss = 1.1448068528689324
# Epoch #16, Loss = 1.1422442505737351
# Epoch #17, Loss = 1.1398275870239543
# Epoch #18, Loss = 1.1375241858512408
# Epoch #19, Loss = 1.1353190052783593
# Epoch #20, Loss = 1.1332040098043337
# Epoch #21, Loss = 1.1311739972083337
# Epoch #22, Loss = 1.129224958118512
# Epoch #23, Loss = 1.1273534292412426
# Epoch #24, Loss = 1.1255562365321488
# Epoch #25, Loss = 1.1238303914646055
# Epoch #26, Loss = 1.122173047476643
# Epoch #27, Loss = 1.1205814801393452
# Epoch #28, Loss = 1.1190530767401743
# Epoch #29, Loss = 1.1175853296644158
# Epoch #30, Loss = 1.1161758313671184
# Epoch #31, Loss = 1.1148222700654804
# Epoch #32, Loss = 1.1135224258065457
# Epoch #33, Loss = 1.1122741667711216
# Epoch #34, Loss = 1.1110754457558245
# Epoch #35, Loss = 1.1099242968070808
# Epoch #36, Loss = 1.10881883199355
# Epoch #37, Loss = 1.1077572383085288
# Epoch #38, Loss = 1.1067377746960367
# Epoch #39, Loss = 1.1057587691952167
# Epoch #40, Loss = 1.104818616198168
# Epoch #41, Loss = 1.1039157738166592
# Epoch #42, Loss = 1.1030487613533566
# Epoch #43, Loss = 1.102216156873417
# Epoch #44, Loss = 1.1014165948724568
# Epoch #45, Loss = 1.100648764037068
# Epoch #46, Loss = 1.0999114050942145
# Epoch #47, Loss = 1.0992033087459734
# Epoch #48, Loss = 1.0985233136862371
# Epoch #49, Loss = 1.097870304696128
# Epoch #50, Loss = 1.09724321081499
# Epoch #51, Loss = 1.096641003583978
# Epoch #52, Loss = 1.096062695359338
# Epoch #53, Loss = 1.095507337692635
# Epoch #54, Loss = 1.0949740197752602
# Epoch #55, Loss = 1.0944618669446682
# Epoch #56, Loss = 1.0939700392498959
# Epoch #57, Loss = 1.0934977300740087
# Epoch #58, Loss = 1.0930441648112175
# Epoch #59, Loss = 1.0926085995964951
# Epoch #60, Loss = 1.092190320085607
# Epoch #61, Loss = 1.0917886402835582
# Epoch #62, Loss = 1.0914029014195359
# Epoch #63, Loss = 1.091032470866498
# Epoch #64, Loss = 1.0906767411036387
# Epoch #65, Loss = 1.090335128720033
# Epoch #66, Loss = 1.0900070734578162
# Epoch #67, Loss = 1.089692037293343
# Epoch #68, Loss = 1.089389503554803
# Epoch #69, Loss = 1.0890989760748606
# Epoch #70, Loss = 1.0888199783769217
# Epoch #71, Loss = 1.088552052893691
# Epoch #72, Loss = 1.0882947602167463
# Epoch #73, Loss = 1.088047678375887
# Epoch #74, Loss = 1.0878104021470911
# Epoch #75, Loss = 1.0875825423879293
# Epoch #76, Loss = 1.0873637253993544
# Epoch #77, Loss = 1.0871535923128235
# Epoch #78, Loss = 1.086951798501737
# Epoch #79, Loss = 1.0867580130162375
# Epoch #80, Loss = 1.0865719180404403
# Epoch #81, Loss = 1.0863932083712007
# Epoch #82, Loss = 1.0862215909175705
# Epoch #83, Loss = 1.0860567842201165
# Epoch #84, Loss = 1.0858985179893152
# Epoch #85, Loss = 1.085746532662269
# Epoch #86, Loss = 1.0856005789770102
# Epoch #87, Loss = 1.0854604175637048
# Epoch #88, Loss = 1.0853258185520727
# Epoch #89, Loss = 1.0851965611943946
# Epoch #90, Loss = 1.0850724335034754
# Epoch #91, Loss = 1.0849532319049762
# Epoch #92, Loss = 1.0848387609035461
# Epoch #93, Loss = 1.0847288327622016
# Epoch #94, Loss = 1.0846232671944278
# Epoch #95, Loss = 1.084521891068506
# Epoch #96, Loss = 1.084424538123566
# Epoch #97, Loss = 1.0843310486969167
# Epoch #98, Loss = 1.0842412694621877
# Epoch #99, Loss = 1.0841550531778732
# Epoch #100, Loss = 1.0840722584458444
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 16.96774364475719
# Epoch #3, Loss = 5.1546142998906985
# Epoch #4, Loss = 2.1763675073574027
# Epoch #5, Loss = 1.4228463550249253
# Epoch #6, Loss = 1.2296774898258707
# Epoch #7, Loss = 1.1777804390976554
# Epoch #8, Loss = 1.1616259145060386
# Epoch #9, Loss = 1.1546337714184909
# Epoch #10, Loss = 1.150102843962013
# Epoch #11, Loss = 1.1463377209072927
# Epoch #12, Loss = 1.1429038123098147
# Epoch #13, Loss = 1.1396843950598785
# Epoch #14, Loss = 1.1366431661986864
# Epoch #15, Loss = 1.133764436234122
# Epoch #16, Loss = 1.1310380512680935
# Epoch #17, Loss = 1.128455578346256
# Epoch #18, Loss = 1.126009327720094
# Epoch #19, Loss = 1.123692090321233
# Epoch #20, Loss = 1.1214970561799087
# Epoch #21, Loss = 1.1194177792195192
# Epoch #22, Loss = 1.117448154501463
# Epoch #23, Loss = 1.1155823993373604
# Epoch #24, Loss = 1.1138150360689552
# Epoch #25, Loss = 1.1121408759252331
# Epoch #26, Loss = 1.1105550037734246
# Epoch #27, Loss = 1.109052763684895
# Epoch #28, Loss = 1.107629745264928
# Epoch #29, Loss = 1.1062817707040942
# Epoch #30, Loss = 1.1050048825126502
# Epoch #31, Loss = 1.1037953319018114
# Epoch #32, Loss = 1.1026495677777606
# Epoch #33, Loss = 1.101564226316066
# Epoch #34, Loss = 1.1005361210858988
# Epoch #35, Loss = 1.0995622336950621
# Epoch #36, Loss = 1.0986397049283558
# Epoch #37, Loss = 1.0977658263532675
# Epoch #38, Loss = 1.0969380323683438
# Epoch #39, Loss = 1.0961538926708962
# Epoch #40, Loss = 1.0954111051219266
# Epoch #41, Loss = 1.0947074889873267
# Epoch #42, Loss = 1.094040978535508
# Epoch #43, Loss = 1.0934096169726633
# Epoch #44, Loss = 1.0928115506978584
# Epoch #45, Loss = 1.0922450238610848
# Epoch #46, Loss = 1.0917083732082964
# Epoch #47, Loss = 1.0912000231982988
# Epoch #48, Loss = 1.0907184813771478
# Epoch #49, Loss = 1.0902623339964925
# Epoch #50, Loss = 1.0898302418629744
# Epoch #51, Loss = 1.0894209364065237
# Epoch #52, Loss = 1.0890332159559892
# Epoch #53, Loss = 1.0886659422111764
# Epoch #54, Loss = 1.0883180369009384
# Epoch #55, Loss = 1.0879884786175011
# Epoch #56, Loss = 1.0876762998177374
# Epoch #57, Loss = 1.0873805839825719
# Epoch #58, Loss = 1.0871004629261978
# Epoch #59, Loss = 1.0868351142471855
# Epoch #60, Loss = 1.0865837589140122
# Epoch #61, Loss = 1.0863456589779226
# Epoch #62, Loss = 1.086120115406396
# Epoch #63, Loss = 1.085906466030876
# Epoch #64, Loss = 1.0857040836027223
# Epoch #65, Loss = 1.085512373951684
# Epoch #66, Loss = 1.0853307742414895
# Epoch #67, Loss = 1.085158751317426
# Epoch #68, Loss = 1.0849958001410636
# Epoch #69, Loss = 1.084841442307522
# Epoch #70, Loss = 1.084695224640933
# Epoch #71, Loss = 1.0845567178639708
# Epoch #72, Loss = 1.0844255153375457
# Epoch #73, Loss = 1.0843012318669605
# Epoch #74, Loss = 1.0841835025710278
# Epoch #75, Loss = 1.0840719818108215
# Epoch #76, Loss = 1.0839663421749217
# Epoch #77, Loss = 1.0838662735181765
# Epoch #78, Loss = 1.0837714820511533
# Epoch #79, Loss = 1.0836816894776067
# Epoch #80, Loss = 1.0835966321774377
# Epoch #81, Loss = 1.0835160604327343
# Epoch #82, Loss = 1.0834397376946316
# Epoch #83, Loss = 1.0833674398888318
# Epoch #84, Loss = 1.08329895475775
# Epoch #85, Loss = 1.0832340812373524
# Epoch #86, Loss = 1.083172628866855
# Epoch #87, Loss = 1.0831144172295555
# Epoch #88, Loss = 1.0830592754231503
# Epoch #89, Loss = 1.0830070415579878
# Epoch #90, Loss = 1.082957562281777
# Epoch #91, Loss = 1.0829106923293683
# Epoch #92, Loss = 1.082866294096268
# Epoch #93, Loss = 1.082824237234653
# Epoch #94, Loss = 1.0827843982706795
# Epoch #95, Loss = 1.082746660241984
# Epoch #96, Loss = 1.0827109123542948
# Epoch #97, Loss = 1.08267704965615
# Epoch #98, Loss = 1.0826449727307779
# Epoch #99, Loss = 1.0826145874042177
# Epoch #100, Loss = 1.0825858044688383
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 10.104236479876079
# Epoch #3, Loss = 2.4476293615151254
# Epoch #4, Loss = 1.3526989565768797
# Epoch #5, Loss = 1.191873106364553
# Epoch #6, Loss = 1.1643032957727821
# Epoch #7, Loss = 1.1560040369668572
# Epoch #8, Loss = 1.150734537874293
# Epoch #9, Loss = 1.1461647839945805
# Epoch #10, Loss = 1.141945559252873
# Epoch #11, Loss = 1.1380106821542981
# Epoch #12, Loss = 1.1343353312397353
# Epoch #13, Loss = 1.1309015827034072
# Epoch #14, Loss = 1.1276934397799903
# Epoch #15, Loss = 1.1246960632926193
# Epoch #16, Loss = 1.1218956041230863
# Epoch #17, Loss = 1.1192791251505216
# Epoch #18, Loss = 1.1168345394839199
# Epoch #19, Loss = 1.114550554341463
# Epoch #20, Loss = 1.1124166188428777
# Epoch #21, Loss = 1.1104228752638219
# Epoch #22, Loss = 1.108560113497263
# Epoch #23, Loss = 1.1068197285072316
# Epoch #24, Loss = 1.105193680577806
# Epoch #25, Loss = 1.103674458173606
# Epoch #26, Loss = 1.1022550432402225
# Epoch #27, Loss = 1.1009288787842868
# Epoch #28, Loss = 1.099689838583409
# Epoch #29, Loss = 1.0985321988860703
# Epoch #30, Loss = 1.097450611970727
# Epoch #31, Loss = 1.0964400814419863
# Epoch #32, Loss = 1.0954959391497399
# Epoch #33, Loss = 1.0946138236246208
# Epoch #34, Loss = 1.0937896599301793
# Epoch #35, Loss = 1.093019640838697
# Epoch #36, Loss = 1.0923002092436784
# Epoch #37, Loss = 1.0916280417277882
# Epoch #38, Loss = 1.091000033210304
# Epoch #39, Loss = 1.0904132826031878
# Epoch #40, Loss = 1.0898650794094948
# Epoch #41, Loss = 1.0893528912022215
# Epoch #42, Loss = 1.0888743519257498
# Epoch #43, Loss = 1.0884272509658395
# Epoch #44, Loss = 1.0880095229376903
# Epoch #45, Loss = 1.087619238144885
# Epoch #46, Loss = 1.087254593665151
# Epoch #47, Loss = 1.086913905021751
# Epoch #48, Loss = 1.0865955984020361
# Epoch #49, Loss = 1.0862982033872117
# Epoch #50, Loss = 1.0860203461597324
# Epoch #51, Loss = 1.0857607431569447
# Epoch #52, Loss = 1.0855181951416644
# Epoch #53, Loss = 1.0852915816622954
# Epoch #54, Loss = 1.0850798558768986
# Epoch #55, Loss = 1.0848820397172996
# Epoch #56, Loss = 1.0846972193709024
# Epoch #57, Loss = 1.0845245410593236
# Epoch #58, Loss = 1.0843632070943632
# Epoch #59, Loss = 1.0842124721930788
# Epoch #60, Loss = 1.084071640034947
# Epoch #61, Loss = 1.0839400600452103
# Epoch #62, Loss = 1.0838171243895416
# Epoch #63, Loss = 1.0837022651661528
# Epoch #64, Loss = 1.0835949517823686
# Epoch #65, Loss = 1.0834946885035535
# Epoch #66, Loss = 1.0834010121630602
# Epoch #67, Loss = 1.083313490022633
# Epoch #68, Loss = 1.083231717773369
# Epoch #69, Loss = 1.083155317668012
# Epoch #70, Loss = 1.0830839367759473
# Epoch #71, Loss = 1.0830172453528388
# Epoch #72, Loss = 1.0829549353173715
# Epoch #73, Loss = 1.0828967188280685
# Epoch #74, Loss = 1.0828423269536094
# Epoch #75, Loss = 1.0827915084304955
# Epoch #76, Loss = 1.0827440285023426
# Epoch #77, Loss = 1.0826996678354186
# Epoch #78, Loss = 1.0826582215054323
# Epoch #79, Loss = 1.0826194980508852
# Epoch #80, Loss = 1.0825833185886122
# Epoch #81, Loss = 1.082549515987433
# Epoch #82, Loss = 1.0825179340960864
# Epoch #83, Loss = 1.0824884270218895
# Epoch #84, Loss = 1.0824608584567872
# Epoch #85, Loss = 1.0824351010476743
# Epoch #86, Loss = 1.0824110358080896
# Epoch #87, Loss = 1.0823885515685545
# Epoch #88, Loss = 1.0823675444630294
# Epoch #89, Loss = 1.0823479174490995
# Epoch #90, Loss = 1.0823295798596908
# Epoch #91, Loss = 1.0823124469842287
# Epoch #92, Loss = 1.082296439677323
# Epoch #93, Loss = 1.0822814839931503
# Epoch #94, Loss = 1.082267510843863
# Epoch #95, Loss = 1.0822544556804394
# Epoch #96, Loss = 1.0822422581944957
# Epoch #97, Loss = 1.0822308620396919
# Epoch #98, Loss = 1.0822202145714437
# Epoch #99, Loss = 1.0822102666037243
# Epoch #100, Loss = 1.082200972181856
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 5.1854027831783505
# Epoch #3, Loss = 1.4312674815096855
# Epoch #4, Loss = 1.1847274831938792
# Epoch #5, Loss = 1.1626728176318957
# Epoch #6, Loss = 1.1554467858854374
# Epoch #7, Loss = 1.1496246092502886
# Epoch #8, Loss = 1.1443132518616959
# Epoch #9, Loss = 1.1394226048234162
# Epoch #10, Loss = 1.1349164231068363
# Epoch #11, Loss = 1.130764296375943
# Epoch #12, Loss = 1.126938394278748
# Epoch #13, Loss = 1.1234130852107411
# Epoch #14, Loss = 1.1201647521653388
# Epoch #15, Loss = 1.1171716337234583
# Epoch #16, Loss = 1.1144136782174936
# Epoch #17, Loss = 1.1118724093968262
# Epoch #18, Loss = 1.1095308026504769
# Epoch #19, Loss = 1.1073731709548618
# Epoch #20, Loss = 1.1053850597824024
# Epoch #21, Loss = 1.1035531502669425
# Epoch #22, Loss = 1.1018651699772468
# Epoch #23, Loss = 1.1003098107008449
# Epoch #24, Loss = 1.0988766526874143
# Epoch #25, Loss = 1.0975560948442058
# Epoch #26, Loss = 1.096339290415861
# Epoch #27, Loss = 1.0952180877177333
# Epoch #28, Loss = 1.0941849755256619
# Epoch #29, Loss = 1.0932330327563593
# Epoch #30, Loss = 1.0923558821012962
# Epoch #31, Loss = 1.0915476473034833
# Epoch #32, Loss = 1.0908029137909163
# Epoch #33, Loss = 1.090116692402971
# Epoch #34, Loss = 1.0894843859667398
# Epoch #35, Loss = 1.0889017584993907
# Epoch #36, Loss = 1.088364906830233
# Epoch #37, Loss = 1.0878702344523776
# Epoch #38, Loss = 1.0874144274288158
# Epoch #39, Loss = 1.086994432191505
# Epoch #40, Loss = 1.0866074350847361
# Epoch #41, Loss = 1.0862508435157299
# Epoch #42, Loss = 1.0859222685861967
# Epoch #43, Loss = 1.085619509088492
# Epoch #44, Loss = 1.0853405367591655
# Epoch #45, Loss = 1.0850834826911022
# Epoch #46, Loss = 1.0848466248132347
# Epoch #47, Loss = 1.0846283763539493
# Epoch #48, Loss = 1.0844272752108954
# Epoch #49, Loss = 1.0842419741559883
# Epoch #50, Loss = 1.08407123180998
# Epoch #51, Loss = 1.0839139043261465
# Epoch #52, Loss = 1.083768937727362
# Epoch #53, Loss = 1.0836353608452356
# Epoch #54, Loss = 1.0835122788140075
# Epoch #55, Loss = 1.083398867075614
# Epoch #56, Loss = 1.0832943658557597
# Epoch #57, Loss = 1.0831980750739962
# Epoch #58, Loss = 1.083109349653704
# Epoch #59, Loss = 1.0830275952005595
# Epoch #60, Loss = 1.0829522640205314
# Epoch #61, Loss = 1.0828828514507438
# Epoch #62, Loss = 1.0828188924786062
# Epoch #63, Loss = 1.0827599586265753
# Epoch #64, Loss = 1.0827056550816763
# Epoch #65, Loss = 1.0826556180505473
# Epoch #66, Loss = 1.0826095123222963
# Epoch #67, Loss = 1.0825670290228362
# Epoch #68, Loss = 1.0825278835456573
# Epoch #69, Loss = 1.0824918136451789
# Epoch #70, Loss = 1.0824585776798952
# Epoch #71, Loss = 1.082427952993559
# Epoch #72, Loss = 1.0823997344235485
# Epoch #73, Loss = 1.0823737329264338
# Epoch #74, Loss = 1.0823497743115236
# Epoch #75, Loss = 1.0823276980739165
# Epoch #76, Loss = 1.0823073563192414
# Epoch #77, Loss = 1.0822886127728706
# Epoch #78, Loss = 1.0822713418669851
# Epoch #79, Loss = 1.0822554278993604
# Epoch #80, Loss = 1.08224076425825
# Epoch #81, Loss = 1.0822272527081653
# Epoch #82, Loss = 1.0822148027317693
# Epoch #83, Loss = 1.0822033309234813
# Epoch #84, Loss = 1.0821927604307164
# Epoch #85, Loss = 1.0821830204390366
# Epoch #86, Loss = 1.0821740456977413
# Epoch #87, Loss = 1.08216577608274
# Epoch #88, Loss = 1.0821581561937614
# Epoch #89, Loss = 1.082151134983217
# Epoch #90, Loss = 1.0821446654142193
# Epoch #91, Loss = 1.0821387041454673
# Epoch #92, Loss = 1.0821332112408943
# Epoch #93, Loss = 1.0821281499021247
# Epoch #94, Loss = 1.082123486221954
# Epoch #95, Loss = 1.0821191889571928
# Epoch #96, Loss = 1.0821152293193643
# Epoch #97, Loss = 1.0821115807818396
# Epoch #98, Loss = 1.082108218902131
# Epoch #99, Loss = 1.082105121158145
# Epoch #100, Loss = 1.0821022667973008
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 2.2112425546640084
# Epoch #3, Loss = 1.1900861969229521
# Epoch #4, Loss = 1.1651488881261263
# Epoch #5, Loss = 1.1573121314647419
# Epoch #6, Loss = 1.1504345882202196
# Epoch #7, Loss = 1.14418930323834
# Epoch #8, Loss = 1.1385145908640621
# Epoch #9, Loss = 1.1333582647711395
# Epoch #10, Loss = 1.128672969293049
# Epoch #11, Loss = 1.124415675746693
# Epoch #12, Loss = 1.1205472861380088
# Epoch #13, Loss = 1.1170322740765541
# Epoch #14, Loss = 1.113838358509096
# Epoch #15, Loss = 1.1109362072579192
# Epoch #16, Loss = 1.1082991676409293
# Epoch #17, Loss = 1.10590302169962
# Epoch #18, Loss = 1.1037257637869737
# Epoch #19, Loss = 1.101747398472717
# Epoch #20, Loss = 1.0999497569099435
# Epoch #21, Loss = 1.0983163299766434
# Epoch #22, Loss = 1.0968321166597723
# Epoch #23, Loss = 1.095483486289434
# Epoch #24, Loss = 1.0942580533579782
# Epoch #25, Loss = 1.0931445637743802
# Epoch #26, Loss = 1.0921327915092842
# Epoch #27, Loss = 1.0912134446815311
# Epoch #28, Loss = 1.0903780802236804
# Epoch #29, Loss = 1.0896190263428454
# Epoch #30, Loss = 1.088929312064728
# Epoch #31, Loss = 1.088302603213816
# Epoch #32, Loss = 1.087733144241785
# Epoch #33, Loss = 1.0872157053698837
# Epoch #34, Loss = 1.086745534559861
# Epoch #35, Loss = 1.0863183138723522
# Epoch #36, Loss = 1.0859301198119287
# Epoch #37, Loss = 1.085577387294627
# Epoch #38, Loss = 1.085256876907049
# Epoch #39, Loss = 1.0849656451563412
# Epoch #40, Loss = 1.0847010174378402
# Epoch #41, Loss = 1.0844605634721292
# Epoch #42, Loss = 1.084242074985912
# Epoch #43, Loss = 1.0840435454317483
# Epoch #44, Loss = 1.0838631515603883
# Epoch #45, Loss = 1.0836992366764737
# Epoch #46, Loss = 1.0835502954238354
# Epoch #47, Loss = 1.0834149599606502
# Epoch #48, Loss = 1.083291987397501
# Epoch #49, Loss = 1.0831802483829702
# Epoch #50, Loss = 1.0830787167319362
# Epoch #51, Loss = 1.0829864600013313
# Epoch #52, Loss = 1.082902630926799
# Epoch #53, Loss = 1.082826459641616
# Epoch #54, Loss = 1.0827572466064157
# Epoch #55, Loss = 1.0826943561847806
# Epoch #56, Loss = 1.0826372108057056
# Epoch #57, Loss = 1.082585285659321
# Epoch #58, Loss = 1.0825381038771587
# Epoch #59, Loss = 1.0824952321527053
# Epoch #60, Loss = 1.0824562767620154
# Epoch #61, Loss = 1.08242087994784
# Epoch #62, Loss = 1.082388716634072
# Epoch #63, Loss = 1.0823594914403178
# Epoch #64, Loss = 1.0823329359691947
# Epoch #65, Loss = 1.082308806341433
# Epoch #66, Loss = 1.082286880956144
# Epoch #67, Loss = 1.0822669584556872
# Epoch #68, Loss = 1.0822488558764531
# Epoch #69, Loss = 1.0822324069685647
# Epoch #70, Loss = 1.0822174606690766
# Epoch #71, Loss = 1.0822038797146518
# Epoch #72, Loss = 1.0821915393809634
# Epoch #73, Loss = 1.0821803263372558
# Epoch #74, Loss = 1.0821701376055448
# Epoch #75, Loss = 1.082160879614888
# Epoch #76, Loss = 1.082152467342052
# Epoch #77, Loss = 1.0821448235306794
# Epoch #78, Loss = 1.0821378779817858
# Epoch #79, Loss = 1.082131566909064
# Epoch #80, Loss = 1.0821258323530911
# Epoch #81, Loss = 1.0821206216490378
# Epoch #82, Loss = 1.0821158869430103
# Epoch #83, Loss = 1.0821115847525706
# Epoch #84, Loss = 1.0821076755674013
# Epoch #85, Loss = 1.082104123486455
# Epoch #86, Loss = 1.0821008958882472
# Epoch #87, Loss = 1.0820979631312664
# Epoch #88, Loss = 1.0820952982817542
# Epoch #89, Loss = 1.0820928768663527
# Epoch #90, Loss = 1.082090676647346
# Epoch #91, Loss = 1.0820886774184348
# Epoch #92, Loss = 1.0820868608191654
# Epoch #93, Loss = 1.0820852101663128
# Epoch #94, Loss = 1.0820837103006649
# Epoch #95, Loss = 1.0820823474478043
# Epoch #96, Loss = 1.0820811090916083
# Epoch #97, Loss = 1.082079983859301
# Epoch #98, Loss = 1.0820789614170094
# Epoch #99, Loss = 1.0820780323748636
# Epoch #100, Loss = 1.0820771882007547
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 1.1817557943330512
# Epoch #3, Loss = 1.1706679902318575
# Epoch #4, Loss = 1.1614498604416594
# Epoch #5, Loss = 1.153190821057283
# Epoch #6, Loss = 1.1457910763672716
# Epoch #7, Loss = 1.139161222829849
# Epoch #8, Loss = 1.133221158710204
# Epoch #9, Loss = 1.1278991162930785
# Epoch #10, Loss = 1.1231307947869158
# Epoch #11, Loss = 1.1188585834432099
# Epoch #12, Loss = 1.1150308655047898
# Epoch #13, Loss = 1.1116013945733747
# Epoch #14, Loss = 1.1085287358616733
# Epoch #15, Loss = 1.1057757655792577
# Epoch #16, Loss = 1.1033092224037977
# Epoch #17, Loss = 1.101099305618547
# Epoch #18, Loss = 1.099119315060781
# Epoch #19, Loss = 1.097345328531058
# Epoch #20, Loss = 1.0957559127657688
# Epoch #21, Loss = 1.0943318644809452
# Epoch #22, Loss = 1.093055978358639
# Epoch #23, Loss = 1.0919128391726698
# Epoch #24, Loss = 1.0908886355422263
# Epoch #25, Loss = 1.0899709930630876
# Epoch #26, Loss = 1.0891488248003611
# Epoch #27, Loss = 1.0884121973363958
# Epoch #28, Loss = 1.0877522107554638
# Epoch #29, Loss = 1.0871608911151858
# Epoch #30, Loss = 1.0866310941055495
# Epoch #31, Loss = 1.0861564187315198
# Epoch #32, Loss = 1.0857311299763703
# Epoch #33, Loss = 1.0853500895113448
# Epoch #34, Loss = 1.085008693614489
# Epoch #35, Loss = 1.0847028175485907
# Epoch #36, Loss = 1.0844287657262017
# Epoch #37, Loss = 1.0841832270596383
# Epoch #38, Loss = 1.083963234956493
# Epoch #39, Loss = 1.08376613147734
# Epoch #40, Loss = 1.0835895352225717
# Epoch #41, Loss = 1.083431312560383
# Epoch #42, Loss = 1.083289551848283
# Epoch #43, Loss = 1.0831625403366762
# Epoch #44, Loss = 1.0830487434754608
# Epoch #45, Loss = 1.0829467863736302
# Epoch #46, Loss = 1.0828554371878745
# Epoch #47, Loss = 1.0827735922394748
# Epoch #48, Loss = 1.0827002626796862
# Epoch #49, Loss = 1.0826345625424876
# Epoch #50, Loss = 1.0825756980403658
# Epoch #51, Loss = 1.0825229579737856
# Epoch #52, Loss = 1.0824757051385019
# Epoch #53, Loss = 1.0824333686268681
# Epoch #54, Loss = 1.0823954369301434
# Epoch #55, Loss = 1.0823614517584597
# Epoch #56, Loss = 1.082331002503769
# Epoch #57, Loss = 1.0823037212788917
# Epoch #58, Loss = 1.0822792784727093
# Epoch #59, Loss = 1.0822573787678111
# Epoch #60, Loss = 1.082237757572477
# Epoch #61, Loss = 1.0822201778238847
# Epoch #62, Loss = 1.0822044271239255
# Epoch #63, Loss = 1.082190315173011
# Epoch #64, Loss = 1.0821776714708822
# Epoch #65, Loss = 1.0821663432566266
# Epoch #66, Loss = 1.082156193663026
# Epoch #67, Loss = 1.0821471000629275
# Epoch #68, Loss = 1.0821389525876695
# Epoch #69, Loss = 1.0821316527996467
# Epoch #70, Loss = 1.0821251125029916
# Epoch #71, Loss = 1.082119252677993
# Epoch #72, Loss = 1.082114002526384
# Epoch #73, Loss = 1.0821092986159548
# Epoch #74, Loss = 1.0821050841141704
# Epoch #75, Loss = 1.0821013081015198
# Epoch #76, Loss = 1.082097924956306
# Epoch #77, Loss = 1.0820948938034483
# Epoch #78, Loss = 1.082092178020629
# Epoch #79, Loss = 1.0820897447958244
# Epoch #80, Loss = 1.0820875647308683
# Epoch #81, Loss = 1.0820856114862685
# Epoch #82, Loss = 1.0820838614629682
# Epoch #83, Loss = 1.0820822935172278
# Epoch #84, Loss = 1.0820808887051634
# Epoch #85, Loss = 1.0820796300538686
# Epoch #86, Loss = 1.0820785023563482
# Epoch #87, Loss = 1.0820774919877871
# Epoch #88, Loss = 1.0820765867409365
# Epoch #89, Loss = 1.0820757756786241
# Epoch #90, Loss = 1.0820750490016153
# Epoch #91, Loss = 1.0820743979302145
# Epoch #92, Loss = 1.0820738145981932
# Epoch #93, Loss = 1.0820732919577474
# Epoch #94, Loss = 1.082072823694347
# Epoch #95, Loss = 1.082072404150445
# Epoch #96, Loss = 1.0820720282571215
# Epoch #97, Loss = 1.082071691472843
# Epoch #98, Loss = 1.0820713897285887
# Epoch #99, Loss = 1.0820711193786925
# Epoch #100, Loss = 1.0820708771567922
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 2.096942502185479
# Epoch #3, Loss = 1.181620289341694
# Epoch #4, Loss = 1.1583432893473535
# Epoch #5, Loss = 1.149275398931257
# Epoch #6, Loss = 1.1414334809712139
# Epoch #7, Loss = 1.1345087581045532
# Epoch #8, Loss = 1.1283918163171336
# Epoch #9, Loss = 1.1229883952179942
# Epoch #10, Loss = 1.1182152645601309
# Epoch #11, Loss = 1.1139989031299795
# Epoch #12, Loss = 1.1102743657174425
# Epoch #13, Loss = 1.1069842827472798
# Epoch #14, Loss = 1.104077976607323
# Epoch #15, Loss = 1.1015106810540638
# Epoch #16, Loss = 1.0992428516718913
# Epoch #17, Loss = 1.097239556764877
# Epoch #18, Loss = 1.0954699392989338
# Epoch #19, Loss = 1.0939067416065695
# Epoch #20, Loss = 1.0925258855331867
# Epoch #21, Loss = 1.0913061015578687
# Epoch #22, Loss = 1.090228601175952
# Epoch #23, Loss = 1.089276787497036
# Epoch #24, Loss = 1.0884359996007378
# Epoch #25, Loss = 1.0876932867124691
# Epoch #26, Loss = 1.0870372087208273
# Epoch #27, Loss = 1.0864576599639448
# Epoch #28, Loss = 1.0859457135705533
# Epoch #29, Loss = 1.0854934839581283
# Epoch #30, Loss = 1.0850940053701472
# Epoch #31, Loss = 1.0847411245815595
# Epoch #32, Loss = 1.0844294061197928
# Epoch #33, Loss = 1.0841540485414007
# Epoch #34, Loss = 1.0839108104747561
# Epoch #35, Loss = 1.0836959452896002
# Epoch #36, Loss = 1.083506143387173
# Epoch #37, Loss = 1.0833384812219926
# Epoch #38, Loss = 1.0831903762700748
# Epoch #39, Loss = 1.0830595472499498
# Epoch #40, Loss = 1.0829439789837625
# Epoch #41, Loss = 1.0828418913572038
# Epoch #42, Loss = 1.0827517119001593
# Epoch #43, Loss = 1.0826720515657293
# Epoch #44, Loss = 1.0826016833345429
# Epoch #45, Loss = 1.0825395233148083
# Epoch #46, Loss = 1.0824846140469715
# Epoch #47, Loss = 1.0824361097558326
# Epoch #48, Loss = 1.0823932633229527
# Epoch #49, Loss = 1.082355414778681
# Epoch #50, Loss = 1.0823219811365499
# Epoch #51, Loss = 1.082292447413453
# Epoch #52, Loss = 1.0822663586972865
# Epoch #53, Loss = 1.082243313139875
# Epoch #54, Loss = 1.0822229557672458
# Epoch #55, Loss = 1.082204973011917
# Epoch #56, Loss = 1.08218908788297
# Epoch #57, Loss = 1.0821750556995233
# Epoch #58, Loss = 1.0821626603218755
# Epoch #59, Loss = 1.0821517108222762
# Epoch #60, Loss = 1.0821420385440372
# Epoch #61, Loss = 1.082133494503693
# Epoch #62, Loss = 1.0821259470961844
# Epoch #63, Loss = 1.0821192800677288
# Epoch #64, Loss = 1.0821133907251468
# Epoch #65, Loss = 1.082108188354063
# Epoch #66, Loss = 1.0821035928216223
# Epoch #67, Loss = 1.0820995333421894
# Epoch #68, Loss = 1.0820959473870302
# Epoch #69, Loss = 1.0820927797211715
# Epoch #70, Loss = 1.0820899815526095
# Epoch #71, Loss = 1.0820875097807585
# Epoch #72, Loss = 1.0820853263325685
# Epoch #73, Loss = 1.0820833975760782
# Epoch #74, Loss = 1.0820816938023798
# Epoch #75, Loss = 1.0820801887680074
# Epoch #76, Loss = 1.0820788592907027
# Epoch #77, Loss = 1.0820776848923397
# Epoch #78, Loss = 1.0820766474834953
# Epoch #79, Loss = 1.0820757310848141
# Epoch #80, Loss = 1.0820749215808783
# Epoch #81, Loss = 1.0820742065027844
# Epoch #82, Loss = 1.0820735748360841
# Epoch #83, Loss = 1.0820730168511252
# Epoch #84, Loss = 1.0820725239531872
# Epoch #85, Loss = 1.0820720885500934
# Epoch #86, Loss = 1.0820717039352687
# Epoch #87, Loss = 1.082071364184437
# Epoch #88, Loss = 1.0820710640643678
# Epoch #89, Loss = 1.0820707989522695
# Epoch #90, Loss = 1.082070564764583
# Epoch #91, Loss = 1.0820703578940822
# Epoch #92, Loss = 1.082070175154312
# Epoch #93, Loss = 1.0820700137305055
# Epoch #94, Loss = 1.0820698711362295
# Epoch #95, Loss = 1.0820697451750843
# Epoch #96, Loss = 1.082069633906871
# Epoch #97, Loss = 1.0820695356177117
# Epoch #98, Loss = 1.0820694487936442
# Epoch #99, Loss = 1.0820693720973042
# Epoch #100, Loss = 1.0820693043473277
# Epoch #1, Loss = 63.868506986115456
# Epoch #2, Loss = 4.956802678221286
# Epoch #3, Loss = 1.3935754675861145
# Epoch #4, Loss = 1.1686929441073393
# Epoch #5, Loss = 1.146372419359988
# Epoch #6, Loss = 1.1373957745671934
# Epoch #7, Loss = 1.1302092310311778
# Epoch #8, Loss = 1.1239889297075834
# Epoch #9, Loss = 1.1185743402972528
# Epoch #10, Loss = 1.113859242265165
# Epoch #11, Loss = 1.1097531588184453
# Epoch #12, Loss = 1.1061774212625193
# Epoch #13, Loss = 1.1030635291786142
# Epoch #14, Loss = 1.100351830166503
# Epoch #15, Loss = 1.0979903766097463
# Epoch #16, Loss = 1.0959339304938416
# Epoch #17, Loss = 1.0941430967865542
# Epoch #18, Loss = 1.0925835687530436
# Epoch #19, Loss = 1.0912254707468423
# Epoch #20, Loss = 1.0900427858865414
# Epoch #21, Loss = 1.0890128576542646
# Epoch #22, Loss = 1.0881159558681284
# Epoch #23, Loss = 1.087334898714081
# Epoch #24, Loss = 1.0866547235964512
# Epoch #25, Loss = 1.0860624005017245
# Epoch #26, Loss = 1.0855465823845192
# Epoch #27, Loss = 1.085097387793921
# Epoch #28, Loss = 1.0847062115760018
# Epoch #29, Loss = 1.0843655600261641
# Epoch #30, Loss = 1.084068907333361
# Epoch #31, Loss = 1.0838105705660999
# Epoch #32, Loss = 1.0835856008053724
# Epoch #33, Loss = 1.0833896883389507
# Epoch #34, Loss = 1.0832190801008683
# Epoch #35, Loss = 1.0830705077744962
# Epoch #36, Loss = 1.0829411251818863
# Epoch #37, Loss = 1.0828284537599664
# Epoch #38, Loss = 1.0827303350790718
# Epoch #39, Loss = 1.0826448894942344
# Epoch #40, Loss = 1.0825704801371003
# Epoch #41, Loss = 1.082505681558687
# Epoch #42, Loss = 1.082449252422271
# Epoch #43, Loss = 1.0824001117232829
# Epoch #44, Loss = 1.0823573180806652
# Epoch #45, Loss = 1.0823200517029732
# Epoch #46, Loss = 1.0822875986837557
# Epoch #47, Loss = 1.082259337325353
# Epoch #48, Loss = 1.082234726229127
# Epoch #49, Loss = 1.0822132939239701
# Epoch #50, Loss = 1.082194629834402
# Epoch #51, Loss = 1.082178376415236
# Epoch #52, Loss = 1.0821642223021393
# Epoch #53, Loss = 1.0821518963468737
# Epoch #54, Loss = 1.0821411624229489
# Epoch #55, Loss = 1.0821318149021812
# Epoch #56, Loss = 1.0821236747155065
# Epoch #57, Loss = 1.0821165859225796
# Epoch #58, Loss = 1.0821104127244494
# Epoch #59, Loss = 1.082105036862078
# Epoch #60, Loss = 1.08210035535087
# Epoch #61, Loss = 1.0820962785078119
# Epoch #62, Loss = 1.0820927282334272
# Epoch #63, Loss = 1.0820896365156387
# Epoch #64, Loss = 1.0820869441268683
# Epoch #65, Loss = 1.0820845994894255
# Epoch #66, Loss = 1.0820825576874389
# Epoch #67, Loss = 1.0820807796064125
# Epoch #68, Loss = 1.0820792311839122
# Epoch #69, Loss = 1.0820778827570385
# Epoch #70, Loss = 1.0820767084941787
# Epoch #71, Loss = 1.082075685900154
# Epoch #72, Loss = 1.082074795385282
# Epoch #73, Loss = 1.0820740198901033
# Epoch #74, Loss = 1.0820733445585713
# Epoch #75, Loss = 1.08207275645346
# Epoch #76, Loss = 1.0820722443085282
# Epoch #77, Loss = 1.0820717983126906
# Epoch #78, Loss = 1.0820714099220727
# Epoch #79, Loss = 1.0820710716963318
# Epoch #80, Loss = 1.082070777156128
# Epoch #81, Loss = 1.0820705206589991
# Epoch #82, Loss = 1.082070297291267
# Epoch #83, Loss = 1.0820701027739104
# Epoch #84, Loss = 1.082069933380588
# Epoch #85, Loss = 1.082069785866258
# Epoch #86, Loss = 1.0820696574050102
# Epoch #87, Loss = 1.082069545535931
# Epoch #88, Loss = 1.0820694481159616
# Epoch #89, Loss = 1.082069363278842
# Epoch #90, Loss = 1.08206928939936
# Epoch #91, Loss = 1.0820692250622181
# Epoch #92, Loss = 1.0820691690349187
# Epoch #93, Loss = 1.0820691202441546
# Epoch #94, Loss = 1.0820690777552495
# Epoch #95, Loss = 1.0820690407542488
# Epoch #96, Loss = 1.0820690085323301
# Epoch #97, Loss = 1.0820689804722234
# Epoch #98, Loss = 1.082068956036385
# Epoch #99, Loss = 1.0820689347567007
# Epoch #100, Loss = 1.0820689162255201

# %% [markdown]
# ## 6. Sklearn ile...

# %% [markdown]
# ❓ Sklearn kullanarak, aynı veri üzerinde bir Doğrusal Regresyon modeli eğitin. Parametrelerini Gradyan İnişiniz ile hesaplananlarla karşılaştırın.

# %%
# YOUR CODE HERE
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(data_X.reshape(-1,1), data_Y)
intercept, slope =  model.intercept_, model.coef_
print("gradient_descent:", a_best, b_best)
print("Linear Regression:", slope, intercept)
# Out:
# gradient_descent: 0.768671510620374 0.00708932115622393
# Linear Regression: [0.76883717] 0.0070177202010620054

# %% [markdown]
# Hemen hemen aynı olmalıdırlar!

# %% [markdown]
# ### 🏁 Tebrikler! İşiniz bittiğinde lütfen egzersizinizi push edin
