# %% [markdown]
# # (Opsiyonal) Olist reviews' - Translations...
#
# * 🇧🇷 Brezilya Portekizcesi bilmiyorsanız, hadi `order_reviews` metinlerini 🇬🇧 İngilizce’ye çevirelim!
#
# * Bunun için `pip install googletrans==4.0.2` yüklemeniz gerekecek.

# %% [markdown]
# ☢️ Bu API ile herhangi bir sorun yaşarsanız, bunu düzeltmek için zaman harcamayın, bu package oldukça dengesiz… Aklınızda bulunsun:
# - bu optional bir challenge
# - Brezilya Portekizcesi ile yazılmış review’ların anlamını görmek için bazı yorumları Google Translate’e kopyalayıp yapıştırarak yine de eski yöntemle yapabilirsiniz.

# %% [markdown]
# ## Review Translator

# %% [markdown]
# 👉 `reviews` dataset’ini load edin ve 1-yıldız rating’e sahip review’lardan bir örnek (sample) seçin.

# %%
# Verileri yükle
from olist.data import Olist
data = Olist().get_data()

# %%
data.keys()
# Out:
# dict_keys(['sellers', 'product_category_name_translation', 'orders', 'order_items', 'customers', 'geolocation', 'order_payments', 'order_reviews', 'products'])

# %% [markdown]
# 👀 20 adet düşük puan alan yorumdan oluşan bir örneklem seçin (rastgele) ve bunu bir listeye dönüştürün.

# %%
# SENİN KODUN BURAYA
low_reviews_sample = data['order_reviews'].dropna().query("review_score==1").sample(20)
low_reviews_sample_list= low_reviews_sample['review_comment_message'].tolist();

# %% [markdown]
# 🗣 Bu göreve başlamadan önce önceden yüklediğiniz `google_translator` paketini kullanarak bu yorumları çevirin:

# %%
# SENİN KODUN BURAYA
from googletrans import Translator
translator = Translator()
translations = []
for review in low_reviews_sample_list:
    translation = await translator.translate(review, src='pt', dest='en')
    print(translation.text, '\n')
    translations.append(translation)
# Out:
# The product purchased was not the one received, I will be contacting the seller.
#
# I order a product using a code and a completely different one arrives.
#
# I did not receive the correct product.
# It was an hdmi switch which was correct. But it didn't arrive.
#
# They sent me a USB hub swith.
#
# Order is still awaiting invoice, the store is terrible
#
# I only received 1 unit
#
# I ordered one product and received another.
#
# The store sells a very expensive product but the quality is terrible
#
# Lack of attention and respect for customers
#
# The product arrived defective and it was not possible to exchange it, as there was no way to replace it.
#
# I bought it and the colors were all wrong and you choose so carefully and it came out all different, I won't buy it again because until you try and manage to change it, it'll be a huge headache.
#
# I bought 2 watches but only 1 arrived. I've sent messages informing them and so far I've had no response.
#
# I am very dissatisfied!
#
# There are two products, I received one, waiting for the second.
#
# I bought the Shape Now HB Adjustable Thermal Abdominal Modeling Belt, but the Slimming Abdominal Modeling Belt arrived.
#
# I didn't receive
#
# I'm still waiting for the product to arrive.
#
# Didn't arrive Didn't arrive
#
# With a Walita Philips mix and it came open.
# I tested it and it's working. I thought it was strange and didn't like that the product came open
#
# About the store nothing to complain about the product I thought was different from what I have
#
# product arrived in half

# %% [markdown]
# **Insights** 💡
# - Bazı kötü review’lar delivery ile ilgili (`wait_time`, kaçırılan teslim tarihi, vb.)
# - Ancak bazı kötü review’lar seller veya ürünle ilgili...
#
# Peki iki olası nedeni nasıl ayırt edebiliriz?
#
# Bu Olist’in mutlaka bilmesi gereken bir şey:
# - bazı ürünleri katalogdan mı çıkarmalı?
# - yoksa bazı seller’ları marketplace’ten mi kaldırmalı?
